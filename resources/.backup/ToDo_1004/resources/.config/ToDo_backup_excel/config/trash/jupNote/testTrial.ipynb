# %%
import pandas as pd
import numpy as np

# %%
list1=['EVALS - HOSPPEDS X5', '11/03', 'TODAY!']
list2=['FM - DIRECT OBSERVATION OF HISTORY', '11/03', 'TODAY!']
list3=['FM - Focused Note', '11/08', '5 Days']
list4=['FM - Oral Presentation', '11/09', '6 Days']
list5=['Story', '11/13', '10 Days']
list6=['FM - Physical Exam (Only 1)', '11/13', '10 Days']

masterList = []
masterList.append(list1)
masterList.append(list2)
masterList.append(list3)
masterList.append(list4)
masterList.append(list5)
masterList.append(list6)

df = pd.DataFrame(masterList, columns= ["assignment", "due date", "days"])

# %%
def dfdark(df):

    propsHead = 'font-family: SF Pro Display; color: #FFFFFF; font-size:1.2em;'
    propsBody = 'font-family: SF Pro Rounded; color: black; font-size:1em;'

    styleList = [{"selector":"th.col_heading",
            "props": f'background-color:grey; text-align: left;{propsHead}'},
        {"selector":"tbody tr:nth-child(even)",
            "props": f"background-color: lightgrey; text-align: left;{propsBody}"},
        {"selector":"tbody tr:nth-child(odd)",
            "props": f"background-color: white; text-align: left;{propsBody}"},
        {"selector":"td.col0",
            "props": "text-align: left"},
        {"selector":"td.col1",
            "props": "text-align: center"},
        {"selector":"td.col2",
            "props": "text-align: center"},
        {"selector":"th.col2",
            "props": "text-align: center"},
            ]
    
    lengthofToday = len(df[df['days'].str.contains("!")])
    if lengthofToday > 0:
        for i in range(lengthofToday):
            tempToday = {}
            dict_keys = ['selector', 'props']
            tempToday[dict_keys[0]] = ""
            tempToday[dict_keys[1]] = 'color: red'
            tempToday['selector'] = (f"tbody tr:nth-child({i+1})")
            styleList.append(tempToday)
            del tempToday
    return styleList

tableDone = df.style.set_table_styles(dfdark(df)).hide()
tableDone
# Out:
# <style type="text/css">
# #T_640b7 th.col_heading {
#   background-color: grey;
#   text-align: left;
#   font-family: SF Pro Display;
#   color: #FFFFFF;
#   font-size: 1.2em;
# }
# #T_640b7 tbody tr:nth-child(even) {
#   background-color: lightgrey;
#   text-align: left;
#   font-family: SF Pro Rounded;
#   color: black;
#   font-size: 1em;
# }
# #T_640b7 tbody tr:nth-child(odd) {
#   background-color: white;
#   text-align: left;
#   font-family: SF Pro Rounded;
#   color: black;
#   font-size: 1em;
# }
# #T_640b7 td.col0 {
#   text-align: left;
# }
# #T_640b7 td.col1 {
#   text-align: center;
# }
# #T_640b7 td.col2 {
#   text-align: center;
# }
# #T_640b7 th.col2 {
#   text-align: center;
# }
# #T_640b7 tbody tr:nth-child(1) {
#   color: red;
# }
# #T_640b7 tbody tr:nth-child(2) {
#   color: red;
# }
# </style>
# <table id="T_640b7">
#   <thead>
#     <tr>
#       <th id="T_640b7_level0_col0" class="col_heading level0 col0" >assignment</th>
#       <th id="T_640b7_level0_col1" class="col_heading level0 col1" >due date</th>
#       <th id="T_640b7_level0_col2" class="col_heading level0 col2" >days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_640b7_row0_col0" class="data row0 col0" >EVALS - HOSPPEDS X5</td>
#       <td id="T_640b7_row0_col1" class="data row0 col1" >11/03</td>
#       <td id="T_640b7_row0_col2" class="data row0 col2" >TODAY!</td>
#     </tr>
#     <tr>
#       <td id="T_640b7_row1_col0" class="data row1 col0" >FM - DIRECT OBSERVATION OF HISTORY</td>
#       <td id="T_640b7_row1_col1" class="data row1 col1" >11/03</td>
#       <td id="T_640b7_row1_col2" class="data row1 col2" >TODAY!</td>
#     </tr>
#     <tr>
#       <td id="T_640b7_row2_col0" class="data row2 col0" >FM - Focused Note</td>
#       <td id="T_640b7_row2_col1" class="data row2 col1" >11/08</td>
#       <td id="T_640b7_row2_col2" class="data row2 col2" >5 Days</td>
#     </tr>
#     <tr>
#       <td id="T_640b7_row3_col0" class="data row3 col0" >FM - Oral Presentation</td>
#       <td id="T_640b7_row3_col1" class="data row3 col1" >11/09</td>
#       <td id="T_640b7_row3_col2" class="data row3 col2" >6 Days</td>
#     </tr>
#     <tr>
#       <td id="T_640b7_row4_col0" class="data row4 col0" >Story</td>
#       <td id="T_640b7_row4_col1" class="data row4 col1" >11/13</td>
#       <td id="T_640b7_row4_col2" class="data row4 col2" >10 Days</td>
#     </tr>
#     <tr>
#       <td id="T_640b7_row5_col0" class="data row5 col0" >FM - Physical Exam (Only 1)</td>
#       <td id="T_640b7_row5_col1" class="data row5 col1" >11/13</td>
#       <td id="T_640b7_row5_col2" class="data row5 col2" >10 Days</td>
#     </tr>
#   </tbody>
# </table>

# %%
import dataframe_image as dfi
dfi.export(tableDone, 'meowmeow.png', dpi=300)
