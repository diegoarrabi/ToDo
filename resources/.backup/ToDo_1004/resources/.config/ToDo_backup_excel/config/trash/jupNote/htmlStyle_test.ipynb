# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index([
                      'Tumour (Positive)', 
                      'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([[
                      'Decision Tree', 'Regression', 'Random'],
                      ['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_21e95">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_21e95_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_21e95_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_21e95_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_21e95_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_21e95_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_21e95_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_21e95_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_21e95_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...

# %%
s = df.style.format('{:.0f}').hide([('Random', 'Tumour'), ('Random', 'Non-Tumour')], axis="columns")

cell_hover = {
    'selector': 'td:hover',
    'props': [('background-color', "#ffffb3")]
}
index_names= {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight: normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}
s.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_e6295 td:hover {
#   background-color: #ffffb3;
# }
# #T_e6295 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_e6295 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_e6295">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_e6295_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_e6295_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_e6295_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_e6295_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_e6295_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_e6295_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
# ...

# %%
s.set_table_styles([
    {'selector': 'th.col_heading', 'props': 'text-align: center;'},
    {'selector': 'th.col_heading.level0', 'props': 'font-size: 1.5em;'},
    {'selector': 'td', 'props': 'text-align: center; font-weight: bold;'},    
], overwrite=False)
# Out:
# <style type="text/css">
# #T_e6295 td:hover {
#   background-color: #ffffb3;
# }
# #T_e6295 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_e6295 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_e6295 th.col_heading {
#   text-align: center;
# }
# #T_e6295 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_e6295 td {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_e6295">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_e6295_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_e6295_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_e6295_level1_col0" class="col_heading level1 col0" >Tumour</th>
# ...

# %%
np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])
df2.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9c19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9c19_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a9c19_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a9c19_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a9c19_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9c19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9c19_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_a9c19_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_a9c19_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_a9c19_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_a9c19_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df3 = pd.DataFrame(np.random.randn(4,4),
                   pd.MultiIndex.from_product([['A', 'B'], ['r1', 'r2']]),
                   columns=['c1','c2','c3','c4'])
df3
# Out:
#             c1        c2        c3        c4
# A r1 -1.048553 -1.420018 -1.706270  1.950775
#   r2 -0.509652 -0.438074 -1.252795  0.777490
# B r1 -1.613898 -0.212740 -0.895467  0.386902
#   r2 -0.510805 -1.180632 -0.028182  0.428332

# %%
idx = pd.IndexSlice
slice_ = idx[idx[:,'r2'], idx[:'c4']]
df3.style.set_properties(**{'background-color': '#ffffb3'}, subset=slice_)
# Out:
# <style type="text/css">
# #T_0b062_row1_col0, #T_0b062_row1_col1, #T_0b062_row1_col2, #T_0b062_row1_col3, #T_0b062_row3_col0, #T_0b062_row3_col1, #T_0b062_row3_col2, #T_0b062_row3_col3 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_0b062">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b062_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_0b062_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_0b062_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_0b062_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b062_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_0b062_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_0b062_row0_col0" class="data row0 col0" >-1.048553</td>
# ...

# %%
# Out:
# <style type="text/css">
# #T_9b6f3 th.col_header; {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_9b6f3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b6f3_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_9b6f3_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_9b6f3_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_9b6f3_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b6f3_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_9b6f3_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_9b6f3_row0_col0" class="data row0 col0" >-1.048553</td>
#       <td id="T_9b6f3_row0_col1" class="data row0 col1" >-1.420018</td>
#       <td id="T_9b6f3_row0_col2" class="data row0 col2" >-1.706270</td>
# ...
